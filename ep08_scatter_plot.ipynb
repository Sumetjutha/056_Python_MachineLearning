# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
rng = np.random

# %%
x = rng.rand(50)*10

# %%
x
# Out:
# array([7.68602523, 4.93320661, 3.66005247, 5.79093513, 3.19859881,
#        7.48242276, 8.6518002 , 7.73982347, 7.21143185, 6.72458542,
#        1.87296576, 3.75512549, 8.37412541, 7.01033735, 3.2305088 ,
#        2.83534898, 2.15851855, 0.92370399, 1.8183578 , 3.86403927,
#        2.90693268, 5.39394093, 0.43411512, 8.78543832, 8.57438296,
#        8.27762496, 8.04339038, 7.64944023, 1.12547781, 5.08034659,
#        9.63271197, 5.82836768, 1.49046478, 3.92751683, 8.28884281,
#        9.08705112, 0.97322393, 7.41061095, 0.7424442 , 2.25950952,
#        2.52841962, 1.38374773, 0.3846377 , 9.21204365, 8.79335146,
#        0.07957325, 9.40562882, 1.70177842, 5.83948829, 4.52299824])

# %%
a = rng.rand()*100

# %%
a
# Out:
# 97.95854712409664

# %%
c = rng.rand()*100

# %%
c
# Out:
# 33.621830418232946

# %%
y = a*x + rng.rand(50)*100

# %%
y
# Out:
# array([ 827.1171741 ,  566.51644943,  446.48130171,  651.83467575,
#         362.23371688,  766.48988892,  924.3631325 ,  802.96935095,
#         720.01186576,  683.79810265,  209.12517268,  395.83217844,
#         907.01983667,  716.11260919,  374.94672647,  310.28646234,
#         247.20307772,  120.71770218,  261.20502465,  426.78828783,
#         305.0828309 ,  564.14377884,   74.16968004,  897.67422902,
#         928.46655037,  898.27696631,  832.84901897,  831.02117869,
#         144.38350399,  552.46027735,  998.12349796,  631.81790902,
#         204.80046594,  432.73296254,  825.45940083,  957.68566546,
#         155.31629155,  762.33547081,  167.03021371,  293.77867298,
#         253.65174051,  182.45449607,   53.15513069,  947.52197402,
#         897.96995943,   32.7599585 , 1009.12326697,  234.14301853,
#         598.29411207,  526.06142126])

# %%
plt.scatter(x,y)
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc="upper center")
plt.title("")
plt.grid()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
